# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv("C://Users/hugoa/Ironhack/Week_5/Mid_bootcamp_project/Data/Cleaned/clean.csv", index_col=0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317 entries, 0 to 370
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   title                      317 non-null    object
#  1   Certificate                305 non-null    object
#  2   Runtime                    317 non-null    int64
#  3   Genre                      317 non-null    object
#  4   IMDB_Rating                317 non-null    float64
#  5   Meta_score                 295 non-null    float64
#  6   Director                   317 non-null    object
#  7   Star1                      317 non-null    object
#  8   Star2                      317 non-null    object
#  9   No_of_Votes                317 non-null    int64
#  10  Gross                      317 non-null    int64
#  11  rank_afc_2007              75 non-null     float64
#  12  rank_afc_1998              71 non-null     float64
# ...

# %% [markdown]
# There are many regions, but huge class imbalance between them

# %%
# Group regions: USA, foreign
def reg(x):
    for value in range(len(x)):
        if "USA" in x:
            return "USA"
        else:
            return "other"
data["reg"]=data["country"].apply(reg)

data["reg"].unique()
# Out:
# array(['USA', 'other'], dtype=object)

# %% [markdown]
# There are many languages, but huge class imbalance between them

# %%
#Group languages: english, foreign
def lang(x):
    for value in range(len(x)):
        if "English" in x:
            return "English"
        else:
            return "other"
data["lang"]=data["language"].apply(lang)

data["lang"].unique()
# Out:
# array(['English', 'other'], dtype=object)

# %%
def split(x):
    
    categorical = x.select_dtypes("object")
    numerical= x.select_dtypes("int64", "float64")
    
    categorical = pd.DataFrame(categorical)
    numerical = pd.DataFrame(numerical)
    return categorical, numerical

# %%
categorical, numerical = split(data)
categorical.head()
# Out:
#                       title Certificate   Genre              Director  \
# 0  The Shawshank Redemption           A   Drama        Frank Darabont
# 1             The Godfather           A   Crime  Francis Ford Coppola
# 2           The Dark Knight          UA  Action     Christopher Nolan
# 3    The Godfather: Part II           A   Crime  Francis Ford Coppola
# 4              12 Angry Men           U   Crime          Sidney Lumet
#
#             Star1           Star2 included_in_1001_book     rated   released  \
# 0     Tim Robbins  Morgan Freeman                  True         R  14-Oct-94
# 1   Marlon Brando       Al Pacino                  True         R  24-Mar-72
# 2  Christian Bale    Heath Ledger                  True     PG-13  18-Jul-08
# 3       Al Pacino  Robert De Niro                  True         R  20-Dec-74
# 4     Henry Fonda     Lee J. Cobb                  True  APPROVED   1-Apr-57
#
#                   genre              director  \
# ...

# %%
numerical= data[['Runtime','IMDB_Rating','No_of_Votes', 'Gross',
        'year', 'metascore']]

# %%
numerical.head()
# Out:
#    Runtime  IMDB_Rating  No_of_Votes      Gross  year  metascore
# 0      142          9.3      2343110   28341469  1994       80.0
# 1      175          9.2      1620367  134966411  1972      100.0
# 2      152          9.0      2303232  534858444  2008       82.0
# 3      202          9.0      1129952   57300000  1974       80.0
# 4       96          9.0       689845    4360000  1957        NaN

# %%
categ_reduced= data[[ 'Certificate','Genre', 'included_in_1001_book', 'rated',
       'language', 'country', "week_name", "month_name", "lang", "reg"]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
def plot_count(df):
    plt_size = len(df.columns)
    fig, ax = plt.subplots(plt_size, figsize=(10,60))
    n = 0
    for i in df.columns:
        if len(df[i].unique())>=6:
            sns.countplot(data=df, y=df[i], ax = ax[n])
            
            n+=1
            
           
            
        else:
            sns.countplot(data=df, x=df[i], ax = ax[n])
            n += 1
            
            
            
            
    plt.tight_layout()
    plt.savefig('../Presentation/'+i+'plot.png')
    plt.show()

# %%
plot_count(categ_reduced)

# %%
def plot_hist(df_continuous):
    plt_size = len(df_continuous.columns)
    fig, ax = plt.subplots(plt_size, figsize=(16,16))
    n = 0
    for i in df_continuous.columns:
        sns.histplot(data=df_continuous, x=df_continuous[i], ax = ax[n])
        n += 1
    
    plt.tight_layout() 
    plt.savefig('../Presentation/'+i+'histplot.png')
    plt.show()

# %%
plot_hist(numerical)

# %%
sns.scatterplot(data=data, x="IMDB_Rating", y="No_of_Votes")
plt.savefig('../Presentation/votes_scatterplot.png')

# %%
sns.scatterplot(data=data, x="IMDB_Rating", y="Gross")
# Out:
# <AxesSubplot: xlabel='IMDB_Rating', ylabel='Gross'>

# %%
numericalpair= numerical[['Runtime','IMDB_Rating','No_of_Votes', 'Gross', 'metascore']]
sns.pairplot(numericalpair)
plt.savefig('../Presentation/pairplot.png')

# %%
def plot_box(df_continuous):
    for i in df_continuous.columns:
        sns.set(rc={"figure.figsize":(16, 16)})
        sns.boxplot(data=df_continuous, x=i)
        plt.show()

# %%
plot_box(numerical)

# %%
data_corr = numerical.corr()

plt.figure(figsize=(30,30))
mask = np.triu(np.ones_like(numerical.corr(), dtype=bool))

sns.heatmap(data_corr, annot=True, mask=mask)  ;
plt.savefig('../Presentation/heatmap.png')

# %%
# Gross and number of votes are correlated
# Gross and rating have a weak positive correlation.

#Several studies back the concept that it is not that relevant to have a good review what is relevant for the product to succeed
# is that there is a great amount of reviews, in other words, there is no such thing as bad press.

# %% [markdown]
# #Outlier Removal

# %% [markdown]
# iqr = np.percentile(data['Gross'],75) - np.percentile(data['Gross'],25)
# upper_limit = np.percentile(data['Gross'],75) + 1.5*iqr
# lower_limit = np.percentile(data['Gross'],25) - 1.5*iqr
#
# data = numerical[(data['Gross']>lower_limit) & (data['Gross']<upper_limit)]
# sns.boxplot(x=(data['Gross']))
# plt.show()

# %% [markdown]
# data.shape

# %%
sns.lineplot(data=data, x="year", y="Gross")
plt.savefig('../Presentation/yearly_gross_plot.png')

# %%
sns.lineplot(data=data, x="year", y="IMDB_Rating")
plt.savefig('../Presentation/year_rating.png')

# %%
sns.lineplot(data=data, x="year", y="metascore")
# Out:
# <AxesSubplot: xlabel='year', ylabel='metascore'>

# %%
#Hollywood golden age
#90s Godfather

# %%
sns.lineplot(data=data, x="year", y="No_of_Votes")
plt.savefig('../Presentation/year_votes.png')

# %%
# No of votes increases with the years, people are more prone to vote for recent movies, maybe it is just that they have not seen the old ones

# %%
data.to_csv("C://Users/hugoa/Ironhack/Week_5/Mid_bootcamp_project/Data/Cleaned/clean_extra_rows.csv")
